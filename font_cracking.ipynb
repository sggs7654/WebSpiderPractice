# %%
import base64
font_face='...'
b = base64.b64decode(font_face)
with open('58.ttf','wb') as f:
    f.write(b)



from fontTools.ttLib import TTFont

font = TTFont('58.ttf')
font.saveXML('58.xml')


import re
import base64
import io
from fontTools.ttLib import TTFont

base64_str = font_face  # 提取前端中的字体加密字符串
b = base64.b64decode(base64_str)
# 解析ttf数据
font = TTFont(io.BytesIO(b))
# 解析映射关系
bestcmap = font['cmap'].getBestCmap()
"""
bestcmap就是camp标签下的数据: {38006: 'glyph00006', 38287: 'glyph00008', 39228: 'glyph00001', 39499: 'glyph00005', 40506: 'glyph00010', 40611: 'glyph00002', 40804: 'glyph00007', 40850: 'glyph00003', 40868: 'glyph00004', 40869: 'glyph00009'}
"""
newmap = dict()
for key in bestcmap.keys():
    value = int(re.search(r'(\d+)', bestcmap[key]).group(1)) - 1  # 把标签中的数字减一，就得到真实的数字映射了
    key = hex(key)  # 注意网页中的字符串是16进制的，所以这里要做一个转换
    newmap[key] = value  # 得到字符与数据间的真实映射关系
    
# 把页面上自定义字体替换成正常字体，这一步就很简单了
response_ = response.text
for key,value in newmap.items():
    key_ = key.replace('0x','&#x') + ';'
    if key_ in response_:
        response_ = response_.replace(key_,str(value))
# Out:
# {38006: 'glyph00006', 38287: 'glyph00008', 39228: 'glyph00001', 39499: 'glyph00005', 40506: 'glyph00010', 40611: 'glyph00002', 40804: 'glyph00007', 40850: 'glyph00003', 40868: 'glyph00004', 40869: 'glyph00009'}
